# %%
# Importing the necessary libraries.
import pandas as pd
import numpy as np

# %%
# Reading the laptop keywords file
df = pd.read_excel(r"C:\Users\Mazahir\Desktop\laptop_keywords_all.xlsx")
df
# Out:
#                                             Sentences   \
# 0    I use my laptop as a software engineer to writ...
# 1    As a graphic designer, I use my laptop to crea...
# 2    I use my laptop as a writer to craft stories, ...
# 3    As a musician, I use my laptop to compose musi...
# 4    I use my laptop as a gamer to play online game...
# ..                                                 ...
# 493  I want a laptop with long battery life and rel...
# 494  I need a laptop to do presentations during lec...
# 495  I want a laptop that can connect to interactiv...
# 496  I want a laptop with a long battery life to la...
# 497  I need a lightweight and portable laptop for e...
#
#                                               Keywords
# 0    software engineer, coding, debugging, testing,...
# 1    graphic designer, digital art, logo design, ma...
# 2    writer, storytelling, poetry, manuscript editi...
# 3    musician, music composition, song recording, a...
# ...

# %%
# removing all the duplicate records
df = df.drop_duplicates()
df
# Out:
#                                             Sentences   \
# 0    I use my laptop as a software engineer to writ...
# 1    As a graphic designer, I use my laptop to crea...
# 2    I use my laptop as a writer to craft stories, ...
# 3    As a musician, I use my laptop to compose musi...
# 4    I use my laptop as a gamer to play online game...
# ..                                                 ...
# 516  I want a laptop with long battery life and rel...
# 517  I need a laptop to do presentations during lec...
# 518  I want a laptop that can connect to interactiv...
# 519  I want a laptop with a long battery life to la...
# 520  I need a lightweight and portable laptop for e...
#
#                                               Keywords
# 0    software engineer, coding, debugging, testing,...
# 1    graphic designer, digital art, logo design, ma...
# 2    writer, storytelling, poetry, manuscript editi...
# 3    musician, music composition, song recording, a...
# ...

# %%
# data type
dtypes_count = df.dtypes.value_counts()
print(dtypes_count)
# Out:
# object    2
# Name: count, dtype: int64

# %%
# Remove rows with empty cells
df = df.dropna()
df
# Out:
#                                             Sentences   \
# 0    I use my laptop as a software engineer to writ...
# 1    As a graphic designer, I use my laptop to crea...
# 2    I use my laptop as a writer to craft stories, ...
# 3    As a musician, I use my laptop to compose musi...
# 4    I use my laptop as a gamer to play online game...
# ..                                                 ...
# 516  I want a laptop with long battery life and rel...
# 517  I need a laptop to do presentations during lec...
# 518  I want a laptop that can connect to interactiv...
# 519  I want a laptop with a long battery life to la...
# 520  I need a lightweight and portable laptop for e...
#
#                                               Keywords
# 0    software engineer, coding, debugging, testing,...
# 1    graphic designer, digital art, logo design, ma...
# 2    writer, storytelling, poetry, manuscript editi...
# 3    musician, music composition, song recording, a...
# ...

# %%
# Out:
#                                             Sentences   \
# 0    I use my laptop as a software engineer to writ...
# 1    As a graphic designer, I use my laptop to crea...
# 2    I use my laptop as a writer to craft stories, ...
# 3    As a musician, I use my laptop to compose musi...
# 4    I use my laptop as a gamer to play online game...
# ..                                                 ...
# 516  I want a laptop with long battery life and rel...
# 517  I need a laptop to do presentations during lec...
# 518  I want a laptop that can connect to interactiv...
# 519  I want a laptop with a long battery life to la...
# 520  I need a lightweight and portable laptop for e...
#
#                                               Keywords
# 0    software engineer, coding, debugging, testing,...
# 1    graphic designer, digital art, logo design, ma...
# 2    writer, storytelling, poetry, manuscript editi...
# 3    musician, music composition, song recording, a...
# ...

# %%
# save DataFrame back to the laptop keywords csv file
#df.to_excel(r"C:\Users\Mazahir\Desktop\laptop_keywords_all.xlsx", index=False)
