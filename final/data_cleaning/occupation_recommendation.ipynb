# %% [markdown]
# <a href="https://colab.research.google.com/github/Rivi9/Laptop-Recommendation-System/blob/Main-Model/laptop_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Necessary Libraries

# %%
# !pip install forex-python

import pandas as pd
import numpy as np
import nltk
from nltk.stem.porter import PorterStemmer
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from forex_python.converter import CurrencyRates

nltk.download('punkt')
# Out:
# Requirement already satisfied: forex-python in /usr/local/lib/python3.10/dist-packages (1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from forex-python) (2.31.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from forex-python) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (2024.2.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Data Cleaning and Formatting

# %% [markdown]
# **Load in the Data and Examine**

# %%
df = pd.read_csv('laptops.csv')

# %%
df.head(3)
# Out:
#    laptop_id                                               name   price  \
# 0          0                      Lenovo Intel Core i5 11th Gen   62990
# 1          1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
# 2          2           ASUS VivoBook 15 (2022) Core i3 10th Gen   33990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1     AMD Ryzen 9 Octa Core Processor  16 GB DDR5 RAM
# 2  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
#
#                                    os     storage  \
# 0         Windows 11 Operating System  512 GB SSD
# 1  64 bit Windows 11 Operating System    1 TB SSD
# 2  64 bit Windows 11 Operating System  512 GB SSD
#
#                                             img_link  display  rating  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6     4.5
# 1  https://rukminim1.flixcart.com/image/312/312/l...     15.6     3.8
# 2  https://rukminim1.flixcart.com/image/312/312/x...     15.6     4.3
#
#    no_of_ratings  no_of_reviews laptop_brand os_brand processor_brand  \
# 0           14.0            1.0       Lenovo  Windows           Intel
# 1            5.0            1.0         ASUS  Windows             AMD
# 2        10406.0         1040.0         ASUS  Windows           Intel
#
#                  usecases
# 0   Business/Professional
# 1                  Gaming
# 2       Home/Everyday use

# %%
df.shape
# Out:
# (796, 16)

# %%
df
# Out:
#      laptop_id                                               name   price  \
# 0            0                      Lenovo Intel Core i5 11th Gen   62990
# 1            1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
# 2            2           ASUS VivoBook 15 (2022) Core i3 10th Gen   33990
# 3            3                            Lenovo Athlon Dual Core   18990
# 4            4                          APPLE 2020 Macbook Air M1   86990
# ..         ...                                                ...     ...
# 791        791                  ASUS EeeBook 12 Celeron Dual Core   18990
# 792        792                     Ultimus S151 Celeron Dual Core   19990
# 793        793                             ASUS Ryzen 5 Hexa Core   54990
# 794        794                     DELL Inspiron Core i3 11th Gen   40990
# 795        795                    ASUS Celeron Dual Core 10th Gen   24540
#
#                                         processor              ram  \
# 0              Intel Core i5 Processor (11th Gen)   16 GB DDR4 RAM
# 1                 AMD Ryzen 9 Octa Core Processor   16 GB DDR5 RAM
# 2              Intel Core i3 Processor (10th Gen)    8 GB DDR4 RAM
# 3                  AMD Athlon Dual Core Processor    4 GB DDR4 RAM
# 4                              Apple M1 Processor    8 GB DDR4 RAM
# ..                                            ...              ...
# 791             Intel Celeron Dual Core Processor    4 GB DDR4 RAM
# 792             Intel Celeron Dual Core Processor  4 GB LPDDR4 RAM
# 793               AMD Ryzen 5 Hexa Core Processor    8 GB DDR4 RAM
# 794            Intel Core i3 Processor (11th Gen)    8 GB DDR4 RAM
# 795  Intel Celeron Dual Core Processor (10th Gen)    4 GB DDR4 RAM
#
#                                      os              storage  \
# 0           Windows 11 Operating System           512 GB SSD
# 1    64 bit Windows 11 Operating System             1 TB SSD
# 2    64 bit Windows 11 Operating System           512 GB SSD
# 3                  DOS Operating System           256 GB SSD
# 4               Mac OS Operating System           256 GB SSD
# ..                                  ...                  ...
# 791  64 bit Windows 11 Operating System             1 TB HDD
# 792         Windows 11 Operating System           128 GB SSD
# 793         Windows 11 Operating System           512 GB SSD
# 794  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD
# 795         Windows 11 Operating System           256 GB SSD
#
#                                               img_link  display  rating  \
# 0    https://rukminim1.flixcart.com/image/312/312/x...     15.6     4.5
# 1    https://rukminim1.flixcart.com/image/312/312/l...     15.6     3.8
# 2    https://rukminim1.flixcart.com/image/312/312/x...     15.6     4.3
# 3    https://rukminim1.flixcart.com/image/312/312/x...     14.0     3.8
# 4    https://rukminim1.flixcart.com/image/312/312/k...     13.3     4.7
# ..                                                 ...      ...     ...
# 791  https://rukminim1.flixcart.com/image/312/312/l...     11.6     4.0
# 792  https://rukminim1.flixcart.com/image/312/312/x...     14.1     NaN
# 793  https://rukminim1.flixcart.com/image/312/312/x...     14.0     4.5
# 794  https://rukminim1.flixcart.com/image/312/312/k...     15.6     4.0
# 795  https://rukminim1.flixcart.com/image/312/312/x...     14.0     NaN
#
#      no_of_ratings  no_of_reviews laptop_brand os_brand processor_brand  \
# 0             14.0            1.0       Lenovo  Windows           Intel
# 1              5.0            1.0         ASUS  Windows             AMD
# 2          10406.0         1040.0         ASUS  Windows           Intel
# 3             18.0            3.0       Lenovo      DOS             AMD
# 4           8865.0          795.0        APPLE    MacOS        Apple M1
# ..             ...            ...          ...      ...             ...
# 791           20.0            1.0         ASUS  Windows           Intel
# 792            NaN            NaN      Ultimus  Windows           Intel
# 793           22.0            5.0         ASUS  Windows             AMD
# 794          801.0          104.0         DELL  Windows           Intel
# 795            NaN            NaN         ASUS  Windows           Intel
#
#                       usecases
# 0        Business/Professional
# 1                       Gaming
# 2            Home/Everyday use
# 3              Budget Friendly
# 4     Multimedia/Entertainment
# ..                         ...
# 791          Student/Education
# 792             Ultra-portable
# 793                     Gaming
# 794      Business/Professional
# 795            Budget Friendly
#
# [796 rows x 16 columns]

# %% [markdown]
# **Data Types and Missing Values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   laptop_id        796 non-null    int64
#  1   name             796 non-null    object
#  2   price            796 non-null    int64
#  3   processor        796 non-null    object
#  4   ram              796 non-null    object
#  5   os               796 non-null    object
#  6   storage          796 non-null    object
#  7   img_link         796 non-null    object
#  8   display          796 non-null    float64
#  9   rating           530 non-null    float64
#  10  no_of_ratings    530 non-null    float64
#  11  no_of_reviews    530 non-null    float64
#  12  laptop_brand     796 non-null    object
#  13  os_brand         796 non-null    object
#  14  processor_brand  796 non-null    object
#  15  usecases         796 non-null    object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 99.6+ KB

# %%
df.isnull().sum()
# Out:
# laptop_id            0
# name                 0
# price                0
# processor            0
# ram                  0
# os                   0
# storage              0
# img_link             0
# display              0
# rating             266
# no_of_ratings      266
# no_of_reviews      266
# laptop_brand         0
# os_brand             0
# processor_brand      0
# usecases             0
# dtype: int64

# %% [markdown]
# **Drop Columns and Null Values**

# %%
df = df.drop(['rating','no_of_ratings','no_of_reviews'], axis = 1)

# %%
df.head()
# Out:
#    laptop_id                                               name   price  \
# 0          0                      Lenovo Intel Core i5 11th Gen   62990
# 1          1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
# 2          2           ASUS VivoBook 15 (2022) Core i3 10th Gen   33990
# 3          3                            Lenovo Athlon Dual Core   18990
# 4          4                          APPLE 2020 Macbook Air M1   86990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1     AMD Ryzen 9 Octa Core Processor  16 GB DDR5 RAM
# 2  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 3      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
# 4                  Apple M1 Processor   8 GB DDR4 RAM
#
#                                    os     storage  \
# 0         Windows 11 Operating System  512 GB SSD
# 1  64 bit Windows 11 Operating System    1 TB SSD
# 2  64 bit Windows 11 Operating System  512 GB SSD
# 3                DOS Operating System  256 GB SSD
# 4             Mac OS Operating System  256 GB SSD
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
# 1  https://rukminim1.flixcart.com/image/312/312/l...     15.6         ASUS
# 2  https://rukminim1.flixcart.com/image/312/312/x...     15.6         ASUS
# 3  https://rukminim1.flixcart.com/image/312/312/x...     14.0       Lenovo
# 4  https://rukminim1.flixcart.com/image/312/312/k...     13.3        APPLE
#
#   os_brand processor_brand                   usecases
# 0  Windows           Intel      Business/Professional
# 1  Windows             AMD                     Gaming
# 2  Windows           Intel          Home/Everyday use
# 3      DOS             AMD            Budget Friendly
# 4    MacOS        Apple M1   Multimedia/Entertainment

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# laptop_id          0
# name               0
# price              0
# processor          0
# ram                0
# os                 0
# storage            0
# img_link           0
# display            0
# laptop_brand       0
# os_brand           0
# processor_brand    0
# usecases           0
# dtype: int64

# %%
df.nunique()
# Out:
# laptop_id          796
# name               506
# price              449
# processor           59
# ram                 22
# os                  11
# storage             16
# img_link           584
# display             21
# laptop_brand        20
# os_brand             4
# processor_brand      6
# usecases             8
# dtype: int64

# %%
df.shape
# Out:
# (796, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.iloc[0].laptop_brand
# Out:
# 'Lenovo'

# %%
df.head(1)
# Out:
#    laptop_id                           name  price  \
# 0          0  Lenovo Intel Core i5 11th Gen  62990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
#
#                             os     storage  \
# 0  Windows 11 Operating System  512 GB SSD
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
#
#   os_brand processor_brand                usecases
# 0  Windows           Intel   Business/Professional

# %%
df['processor'] = df['processor'].apply(lambda x:x.split())
df['ram'] = df['ram'].apply(lambda x:x.split())
df['os'] = df['os'].apply(lambda x:x.split())
df['use'] = df['usecases'].apply(lambda x:x.split())

# %%
df['tags'] = df['processor']+df['ram']+df['os']+df['use']

# %%
df.head(1)
# Out:
#    laptop_id                           name  price  \
# 0          0  Lenovo Intel Core i5 11th Gen  62990
#
#                                    processor                  ram  \
# 0  [Intel, Core, i5, Processor, (11th, Gen)]  [16, GB, DDR4, RAM]
#
#                                  os     storage  \
# 0  [Windows, 11, Operating, System]  512 GB SSD
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
#
#   os_brand processor_brand                usecases                      use  \
# 0  Windows           Intel   Business/Professional  [Business/Professional]
#
#                                                 tags
# 0  [Intel, Core, i5, Processor, (11th, Gen), 16, ...

# %%
df.iloc[0].tags
# Out:
# ['Intel',
#  'Core',
#  'i5',
#  'Processor',
#  '(11th',
#  'Gen)',
#  '16',
#  'GB',
#  'DDR4',
#  'RAM',
#  'Windows',
#  '11',
#  'Operating',
#  'System',
#  'Business/Professional']

# %%
new = df.drop(columns=['processor','ram','os','storage','os_brand','processor_brand','use'])

# %%
new.head(2)
# Out:
#    laptop_id                                               name   price  \
# 0          0                      Lenovo Intel Core i5 11th Gen   62990
# 1          1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
# 1  https://rukminim1.flixcart.com/image/312/312/l...     15.6         ASUS
#
#                  usecases                                               tags
# 0   Business/Professional  [Intel, Core, i5, Processor, (11th, Gen), 16, ...
# 1                  Gaming  [AMD, Ryzen, 9, Octa, Core, Processor, 16, GB,...

# %%
new['tags'] = new['tags'].apply(lambda x:" ".join(x))

# %%
new.iloc[0].tags
# Out:
# 'Intel Core i5 Processor (11th Gen) 16 GB DDR4 RAM Windows 11 Operating System Business/Professional'

# %%
new.head(2)
# Out:
#    laptop_id                                               name   price  \
# 0          0                      Lenovo Intel Core i5 11th Gen   62990
# 1          1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
# 1  https://rukminim1.flixcart.com/image/312/312/l...     15.6         ASUS
#
#                  usecases                                               tags
# 0   Business/Professional  Intel Core i5 Processor (11th Gen) 16 GB DDR4 ...
# 1                  Gaming  AMD Ryzen 9 Octa Core Processor 16 GB DDR5 RAM...

# %%
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
new['tags'] = new['tags'].apply(stem)

# %%
new.iloc[0].tags
# Out:
# 'intel core i5 processor (11th gen) 16 gb ddr4 ram window 11 oper system business/profession'

# %%
new.head(2)
# Out:
#    laptop_id                                               name   price  \
# 0          0                      Lenovo Intel Core i5 11th Gen   62990
# 1          1  ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  161990
#
#                                             img_link  display laptop_brand  \
# 0  https://rukminim1.flixcart.com/image/312/312/x...     15.6       Lenovo
# 1  https://rukminim1.flixcart.com/image/312/312/l...     15.6         ASUS
#
#                  usecases                                               tags
# 0   Business/Professional  intel core i5 processor (11th gen) 16 gb ddr4 ...
# 1                  Gaming  amd ryzen 9 octa core processor 16 gb ddr5 ram...

# %%
currency_rates = CurrencyRates()

new['price'] = new['price'].apply(lambda x: round(currency_rates.convert(base_cur='INR', dest_cur='USD', amount=x), 2))

# %%
new['usecases'] = new['usecases'].str.replace(' Gaming','Gaming')
new['usecases'] = new['usecases'].str.replace(' Business/Professional','Business/Professional')
new['usecases'] = new['usecases'].str.replace(' Multimedia/Entertainment','IT')
new['usecases'] = new['usecases'].str.replace(' Student/Education','Student/Education')
new['usecases'] = new['usecases'].str.replace(' Creative/Design','Creative/Design')
new['usecases'] = new['usecases'].str.replace(' Travel/On-the-go','Basic')
new['usecases'] = new['usecases'].str.replace(' Home/Everyday use','Basic')
new['usecases'] = new['usecases'].str.replace(' Programming/Development','IT')
new['usecases'] = new['usecases'].str.replace(' Budget Friendly','Basic')
new['usecases'] = new['usecases'].str.replace('Ultra-portable','IT')

# %%
new.groupby('usecases').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Vectorization

# %% [markdown]
# **Word2Vec**

# %%
# Tokenize the tags
new['tags_tokens'] = new['tags'].apply(word_tokenize)

# %%
# Train the Word2Vec model
model = Word2Vec(sentences=new['tags_tokens'], vector_size=100, window=5, min_count=1, workers=4)

# %%
# Get the Word2Vec vectors for each laptop
word2vec_vectors = []
for tags_tokens in new['tags_tokens']:
    vectors = [model.wv[word] for word in tags_tokens if word in model.wv]
    if vectors:
        word2vec_vectors.append(np.mean(vectors, axis=0))
    else:
        word2vec_vectors.append(np.zeros(100))

# %%
word2vec_vectors = np.array(word2vec_vectors)

# %% [markdown]
# **Cosine Similarity**

# %%
word2vec_similarity = cosine_similarity(word2vec_vectors)

# %%
#Print the similarity of the first laptop with others
print(word2vec_similarity[0])
# Out:
# [0.9999998  0.99932927 0.9999597  0.99955404 0.99953413 0.99973464
#  0.99996346 0.9999911  0.9995726  0.9999869  0.9999777  0.9999948
#  0.99998224 0.99995714 0.99996346 0.99935955 0.99940157 0.9999735
#  0.99953413 0.9999632  0.9999857  0.9995228  0.99996346 0.9999782
#  0.99962854 0.9999777  0.99940157 0.99940544 0.9999777  0.9999998
#  0.99927706 0.9993583  0.9999836  0.9999777  0.99979687 0.99940157
#  0.99997795 0.9999857  0.99995714 0.99996215 0.9999869  0.9999836
#  0.9997514  0.99996346 0.99946636 0.9999869  0.99996346 0.9999857
#  0.99941283 0.9999695  0.99937636 0.99998176 0.99997425 0.9999874
#  0.9993776  0.99997395 0.9995461  0.9999908  0.9993776  0.9999782
#  0.9999777  0.9999535  0.9996595  0.9996595  0.99997425 0.99996245
#  0.9993502  0.9999679  0.99938536 0.9999871  0.9996718  0.9995726
#  0.9993276  0.99997425 0.99998105 0.99928916 0.99998796 0.9999836
#  0.99998105 0.9999911  0.9996827  0.9999777  0.99997807 0.9993276
#  0.99935085 0.99996215 0.9999814  0.9998291  0.9999826  0.99938536
#  0.9993185  0.999243   0.9999733  0.9993776  0.99996793 0.999962
#  0.999333   0.99938536 0.99927706 0.999951   0.99996346 0.9995726
#  0.99938536 0.9999617  0.99997586 0.99940157 0.9993647  0.99922794
#  0.99997056 0.9993276  0.99996793 0.99940157 0.99995714 0.9999713
#  0.99927706 0.99997616 0.9999555  0.9997134  0.9999725  0.9993666
#  0.9999626  0.99997073 0.99996907 0.99922794 0.99997616 0.9999759
#  0.9999823  0.99935955 0.9999733  0.9999851  0.9999719  0.9999791
#  0.99998647 0.9999535  0.9999911  0.9999857  0.9999813  0.99996394
#  0.9999515  0.99938536 0.99997073 0.9999623  0.99996346 0.9993347
#  0.99938536 0.9999911  0.99995714 0.99997514 0.9999762  0.99938536
#  0.99922794 0.99997056 0.99996793 0.99997836 0.9995726  0.99947983
#  0.99932927 0.9999845  0.9999791  0.99933106 0.9999666  0.999705
#  0.99996793 0.999959   0.99997836 0.9993264  0.99997807 0.9999656
#  0.9999583  0.9997306  0.99997616 0.9993131  0.9999672  0.99996585
#  0.9999541  0.9997393  0.99940974 0.9999538  0.9997658  0.9999781
#  0.9996961  0.99997914 0.99995774 0.99969584 0.9999863  0.99996537
#  0.99976844 0.9999998  0.9999532  0.99994695 0.9999642  0.99997264
#  0.9999846  0.99937636 0.9994014  0.99997276 0.9999836  0.99997056
#  0.99997425 0.99922794 0.9999652  0.99935085 0.99997264 0.99997133
#  0.99996907 0.9999908  0.99990404 0.99976933 0.99929154 0.9999732
#  0.9999624  0.99998236 0.99963295 0.9999733  0.99996203 0.9999857
#  0.99932927 0.99997616 0.9997464  0.99972165 0.99997866 0.9993502
#  0.9999719  0.99997586 0.9996961  0.99995005 0.99997413 0.99996215
#  0.99996215 0.99998033 0.99997056 0.99965066 0.9999682  0.9999791
#  0.99994856 0.9997805  0.9999813  0.9998841  0.99996215 0.9997805
#  0.9999236  0.9995067  0.99951565 0.9993502  0.9992687  0.9999541
#  0.9999697  0.99997056 0.99997157 0.9999814  0.99997616 0.9999727
#  0.99997455 0.99995863 0.9999608  0.9996961  0.99995667 0.99938536
#  0.999968   0.99997234 0.99928916 0.9999683  0.99937624 0.9993583
#  0.9993776  0.9993276  0.9999857  0.9999687  0.9999739  0.9996595
#  0.999951   0.99998504 0.9995067  0.9994795  0.9999891  0.9999783
#  0.9999676  0.9999622  0.9999685  0.9999907  0.99997365 0.9997791
#  0.9997512  0.99935085 0.9999777  0.99991775]

# %% [markdown]
# # Recommendation

# %%
# def recommends(laptop):
#     index = new[new['usecases']==laptop].index[0]
#     distances = sorted(list(enumerate(word2vec_similarity[index])), reverse=True, key = lambda x:x[1])
#     for i in distances[1:10]:
#         print(new.iloc[i[0]].price)

# %%
def recommends():
  use = input('Enter the Workfield :-')
  index = new[new['usecases'] == use].index[0]
  distances = sorted(list(enumerate(word2vec_similarity[index])), reverse=True, key=lambda x: x[1])
  printed_names = set()
  for i in distances[1:50]:
    row_index = i[0]
    name = new.iloc[row_index]['name']
    price = new.iloc[row_index]['price']
    if name not in printed_names:
      printed_names.add(name)
      print(name)
      print(price)

# %%
# sorted(list(enumerate(word2vec_similarity[0])), reverse=True, key = lambda x:x[1])

# %%
recommends()
# Out:
# Enter the Workfield :-Gaming
# ASUS Ryzen 9 Octa Core 6900HX
# 2541.85
# ASUS ROG Zephyrus G15 (2022) with 90Whr Battery Ryzen 9 Octa Core 6900HS
# 2011.77
# ASUS ROG Zephyrus G15 Ryzen 9 Octa Core 6900HS
# 2288.85
# ASUS ROG Zephyrus G14 (2022) Ryzen 9 Octa Core AMD R9
# 2312.95
# HP Ryzen 9 Octa Core 6900HX
# 1929.73
# ASUS ROG Strix G15 (2022) with 90Whr Battery Ryzen 9 Octa Core 6900HX
# 2144.29
# ASUS ROG Flow X16 (2022) with 90Whr Battery Ryzen 7 Octa Core AMD R7
# 2072.0
# ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AMD R7
# 1204.6
# ASUS ROG Strix G15 (2022) with 90Whr Battery Ryzen 7 Octa Core 6800H
# 1566.02
# Lenovo Legion 5 Pro Ryzen 7 Octa Core 6800H
# 1927.44
# ASUS ROG Zephyrus G15 (2022) with 90Whr Battery Ryzen 7 Octa Core 6800HS
# 1963.58
# HP Victus Ryzen 7 Octa Core 6800H
# 1343.27
# HP Ryzen 7 Octa Core 6800H
# 1202.92
# HP OMEN Ryzen 7 Octa Core AMD R7
# 1304.6
# DELL Ryzen 9 Octa Core 6900HX
# 1770.82
# ASUS ROG Zephyrus G15 (2022) Ryzen 9 Octa Core 6900HS
# 3071.92
# ASUS ROG Flow X16 (2022) with 90Whr Battery Ryzen 9 Octa Core 6900HS
# 3156.26
# Lenovo Legion 5 Ryzen 7 Octa Core 5800H
# 1400.49
# ASUS Vivobook Pro 15 OLED Ryzen 7 Octa Core AMD R7
# 795.0
# ASUS TUF Gaming A15 with 90Whr Battery Ryzen 7 Octa Core 5800H
# 1084.13
# ASUS TUF Gaming A17 (2022) with 90Whr Battery Ryzen 7 Octa Core AMD R7
# 1072.08
# Lenovo IdeaPad Gaming Ryzen 7 Octa Core 5800H
# 1084.13
# DELL Ryzen 7 Octa Core AMD R7
# 1066.06
# ASUS ROG Strix G15 with 90Whr Battery Ryzen 7 Octa Core 5800H
# 1770.82
# Lenovo Legion 5 Pro Ryzen 7 Octa Core 5800H
# 1566.01
# ASUS TUF GAMING A15 Ryzen 7 Octa Core 4800H
# 975.71
# DELL Inspiron Ryzen 7 Octa Core 5700U
# 1070.88
# HP Victus Ryzen 7 Octa Core 5800H
# 1300.98
# HP HP Envy Ryzen 7 Octa Core 4700U
# 983.05
# ASUS ROG Strix G15 Advantage Edition with 90Whr Battery Ryzen 9 Octa Core 5980HX
# 1819.01
# ASUS ROG Zephyrus G15 (2020) Ryzen 9 Octa Core 4900HS
# 1566.02
# ASUS ROG Zephyrus Duo 16 (2022) Dual Screen Laptop with 90Whr Battery Ryzen 7 Octa Core 6800H
# 2710.51
# Lenovo Legion 5 Pro Ryzen 7 Octa Core Ryzen™ 7 5800H
# 2168.49

# %% [markdown]
# # Export the Dataframe and the Model

# %%
pickle.dump(new, open('dataframe.pkl','wb'))
pickle.dump(word2vec_similarity, open('word2vec_similarity.pkl','wb'))
