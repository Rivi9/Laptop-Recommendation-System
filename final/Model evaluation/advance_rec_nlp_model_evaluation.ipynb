# %%
evaluation_data = [
    ("This laptop has an NVIDIA GeForce GTX 1660 Ti GPU, priced at $1200 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1200.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580, priced at $900 with 8GB of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("I need a laptop with 16GB RAM, AMD Radeon Pro 455 and with a price of $1500", ("AMD Radeon Pro 455", "1500.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3070 GPU, priced at $2000 with 32GB of RAM.", ("NVIDIA GeForce RTX 3070", "2000.0", "32")),
    ("This laptop features an Intel Iris Xe Graphics, priced at $1100 with 16GB RAM.", ("Intel Iris Xe Graphics", "1100.0", "16")),
    ("The laptop comes with an NVIDIA Quadro RTX 5000 GPU, priced at $2500 with 64GB of RAM.", ("NVIDIA Quadro RTX 5000", "2500.0", "64")),
    ("I want a laptop with AMD Radeon RX Vega 10 GPU, priced at $800 with 8GB RAM.", ("AMD Radeon RX Vega 10", "800.0", "8")),
    ("This laptop has an NVIDIA GeForce GTX 1650 Ti GPU, priced at $1500 with 32GB RAM.", ("NVIDIA GeForce GTX 1650 Ti", "1500.0", "32")),
    ("I'm interested in a laptop with NVIDIA GeForce GTX 1660 Ti, priced at 1400 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1400.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580 GPU, priced at $900 with 8GB of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("This laptop has an Intel Iris Xe Graphics, priced at $1200 with 32GB RAM.", ("Intel Iris Xe Graphics", "1200.0", "32")),
    ("Looking for a laptop with NVIDIA Quadro RTX 5000, priced at $2500 with 64GB of RAM.", ("NVIDIA Quadro RTX 5000", "2500.0", "64")),
    ("I want a laptop with AMD Radeon RX 580 GPU, priced at $1000 with 16GB RAM.", ("AMD Radeon RX 580", "1000.0", "16")),
    ("I want a laptop with Radeon RX 580, priced at $1000 with 16GB RAM.", ("AMD Radeon RX 580", "1000.0", "16")),
    ("Looking for a laptop with AMD Ryzen 7 5800H CPU, priced at $1500 with 16GB of RAM.", ("AMD Ryzen 7 5800H", "1500.0", "16")),
    ("This laptop has an NVIDIA GeForce GTX 1660 Ti GPU, priced at $1200 with 16 GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1200.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580 GPU, priced at 900 with 8GB of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("I need a laptop with 16GB RAM, AMD Radeon Pro 455 and with a price of $1500", ("AMD Radeon Pro 455", "1500.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3070 GPU, priced at 2000 with 32GB of RAM.", ("NVIDIA GeForce RTX 3070", "2000.0", "32")),
    ("This laptop features an Intel Iris Xe Graphics, priced at $1100 with 16GB RAM.", ("Intel Iris Xe Graphics", "1100.0", "16")),
    ("The laptop comes with an NVIDIA Quadro RTX 5000 GPU, priced at 2500 with 64 GB of RAM.", ("NVIDIA Quadro RTX 5000", "2500.0", "64")),
    ("This laptop comes with NVIDIA GeForce GTX 1650 Ti GPU, priced at $1100 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Ti", "1100.0", "16")),
    ("I want a laptop with AMD Ryzen 7 5800X CPU, priced at $1600 with 32GB of RAM.", ("AMD Ryzen 7 5800X", "1600.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3080 GPU, priced at $2500 with 64GB of RAM.", ("NVIDIA GeForce RTX 3080", "2500.0", "64")),
    ("This laptop features Intel Core i7-1165G7 CPU, priced at $1300 with 16GB RAM.", ("Intel Core i7-1165G7", "1300.0", "16")),
    ("This laptop features AMD Radeon RX 6800, priced at $2200 with 32GB RAM.", ("AMD Radeon RX 6800", "2200.0", "32")),
    ("I want a laptop with NVIDIA GeForce RTX 3050 GPU, priced at 1200 with 8GB of RAM.", ("NVIDIA GeForce RTX 3050", "1200.0", "8")),
    ("This laptop comes with NVIDIA GeForce RTX 3070 Ti GPU, priced at $2300 with 32GB RAM.", ("NVIDIA GeForce RTX 3070 Ti", "2300.0", "32")),
    ("Looking for a laptop with AMD Ryzen 9 5980HS CPU, priced at $2500 with 32GB of memory.", ("AMD Ryzen 9 5980HS", "2500.0", "32")),
    ("This laptop features Intel UHD Graphics 750, priced at $1000 with 8GB RAM.", ("Intel UHD Graphics 750", "1000.0", "8")),
    ("I want a laptop with AMD Radeon RX 6700M GPU, priced at $2000 with 16 GB of RAM.", ("AMD Radeon RX 6700M", "2000.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1650 Max GPU, priced at $1200 with 8 of RAM.", ("NVIDIA GeForce GTX 1650 Max", "1200.0", "8")),
    ("I need a laptop with NVIDIA GeForce RTX 3060 Ti GPU, priced at $1800 with 16GB of RAM.", ("NVIDIA GeForce RTX 3060 Ti", "1800.0", "16")),
    ("Looking for a laptop with AMD Ryzen 7 5700U CPU, priced at $1300 with 16GB of memory.", ("AMD Ryzen 7 5700U", "1300.0", "16")),
    ("This laptop features AMD Radeon RX 6600 XT GPU, priced at 2200 with 32GB RAM.", ("AMD Radeon RX 6600 XT", "2200.0", "32")),
    ("This laptop has an NVIDIA GeForce GTX 1660 Ti GPU, priced at $1200 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1200.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580 GPU, priced at $900 with 8 of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("I need a laptop with 16GB RAM, AMD Radeon Pro 455 and with a price of $1500", ("AMD Radeon Pro 455", "1500.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3070 GPU, priced at $2000 with 32GB of RAM.", ("NVIDIA GeForce RTX 3070", "2000.0", "32")),
    ("This laptop features an Intel Iris Xe Graphics, priced at $1100 with 16 RAM.", ("Intel Iris Xe Graphics", "1100.0", "16")),
    ("The laptop comes with an NVIDIA Quadro RTX 5000 GPU, priced at $2500 with 64 of RAM.", ("NVIDIA Quadro RTX 5000", "2500.0", "64")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3050 Ti GPU, priced at 1400 with 16GB RAM.", ("NVIDIA GeForce RTX 3050 Ti", "1400.0", "16")),
    ("This laptop features AMD Ryzen 7 5700G CPU, priced at $1500 with 32GB of RAM.", ("AMD Ryzen 7 5700G", "1500.0", "32")),
    ("I need a laptop with AMD Radeon RX 6700 XT GPU, priced at $2000 with 16GB of RAM.", ("AMD Radeon RX 6700 XT", "2000.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1660 Ti GPU, priced at $1300 with 8GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1300.0", "8")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3070 GPU, priced at 2500 with 32GB of RAM.", ("NVIDIA GeForce RTX 3070", "2500.0", "32")),
    ("This laptop features AMD Ryzen 9 5900HX CPU, priced at $1800 with 16 RAM.", ("AMD Ryzen 9 5900HX", "1800.0", "16")),
    ("This laptop comes with NVIDIA GeForce GTX 1650 GPU, priced at $1000 with 8GB of RAM.", ("NVIDIA GeForce GTX 1650", "1000.0", "8")),
    ("I want a laptop with AMD Ryzen 5 5600U CPU, priced at $1200", ("AMD Ryzen 5 5600U", "1200.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3060 GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce RTX 3060", "1500.0", "0")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3080 Ti GPU, priced at $3000 with 64GB of RAM.", ("NVIDIA GeForce RTX 3080 Ti", "3000.0", "64")),
    ("This laptop features AMD Radeon RX 5600 XT GPU, priced at $1800 with 32 RAM.", ("AMD Radeon RX 5600 XT", "1800.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3060 Ti GPU, priced at 2200 with 32GB of RAM.", ("NVIDIA GeForce RTX 3060 Ti", "2200.0", "32")),
    ("This laptop features AMD Radeon RX 6700 XT GPU, priced at $2700 with 32GB RAM.", ("AMD Radeon RX 6700 XT", "2700.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3050 GPU, priced at $1200 with 8GB RAM.", ("NVIDIA GeForce RTX 3050", "1200.0", "8")),
    
    ("This laptop is equipped with an NVIDIA GeForce RTX 3060 GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce RTX 3060", "1400.0", "16")),
    ("Looking for a laptop featuring AMD Ryzen 7 4800H CPU, priced at $1200 with 16GB of memory.", ("AMD Ryzen 7 4800H", "1200.0", "16")),
    ("This laptop comes with an Intel Core i9-11900K CPU, priced at $2500 with 32GB RAM.", ("Intel Core i9-11900K", "2500.0", "32")),
    ("I'm interested in a laptop with AMD Radeon RX 6800M GPU, priced at $2000 with 16GB of RAM.", ("AMD Radeon RX 6800M", "2000.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1650 GPU, priced at 1000 with 8GB RAM.", ("NVIDIA GeForce GTX 1650", "1000.0", "8")),
    ("This laptop features an AMD Ryzen 5 5600X CPU, priced at $1500 with 16GB of memory.", ("AMD Ryzen 5 5600X", "1500.0", "16")),
    ("I want a laptop with Intel UHD Graphics, priced at $800 with 8GB RAM.", ("Intel UHD Graphics", "800.0", "8")),
    ("The laptop comes with NVIDIA GeForce RTX 3080 GPU, priced at $3000 with 32GB of RAM.", ("NVIDIA GeForce RTX 3080", "3000.0", "32")),
    ("This laptop has an AMD Ryzen 9 5900HX CPU, priced at $2000 with 16GB RAM.", ("AMD Ryzen 9 5900HX", "2000.0", "16")),
    ("The laptop comes with Intel Iris Xe Graphics, priced at $900 with 8GB of RAM.", ("Intel Iris Xe Graphics", "900.0", "8")),
    ("I need a laptop with NVIDIA GeForce GTX 1660 Super GPU, priced at $1200 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Super", "1200.0", "16")),
    ("Looking for a laptop with AMD Radeon RX 6700 XT GPU, priced at $1800 with 32GB of RAM.", ("AMD Radeon RX 6700 XT", "1800.0", "32")),
    ("This laptop features an Intel Core i7-11800H CPU, priced at $1700 with 16GB RAM.", ("Intel Core i7-11800H", "1700.0", "16")),
    ("I want a laptop with NVIDIA GeForce MX450 GPU, priced at $1100 with 8GB RAM.", ("NVIDIA GeForce MX450", "1100.0", "8")),
    ("This laptop has an AMD Ryzen 7 5800H CPU, priced at $1500 with 16GB RAM.", ("AMD Ryzen 7 5800H", "1500.0", "16")),
    ("The laptop comes with Intel UHD Graphics 630, priced at $800 with 8GB of RAM.", ("Intel UHD Graphics 630", "800.0", "8")),
    ("I need a laptop with NVIDIA GeForce GTX 1650 Ti GPU, priced at 1300 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Ti", "1300.0", "16")),
    ("Looking for a laptop with AMD Ryzen 5 5600G CPU, priced at $1000 with 8GB of memory.", ("AMD Ryzen 5 5600G", "1000.0", "8")),
    ("This laptop features an Intel Core i5-11300H CPU, priced at $1200 with 16GB RAM.", ("Intel Core i5-11300H", "1200.0", "16")),
    ("I want a laptop with NVIDIA GeForce RTX 3060 Ti GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce RTX 3060 Ti", "1400.0", "16")),
    ("This laptop comes with AMD Radeon RX 6600M GPU, priced at $1700 with 16GB RAM.", ("AMD Radeon RX 6600M", "1700.0", "16")),
    ("Looking for a laptop featuring Intel Core i9-12900K CPU, priced at $3000 with 32GB of memory.", ("Intel Core i9-12900K", "3000.0", "32")),
    ("This laptop has NVIDIA GeForce RTX 3050 Ti GPU, priced at $1200 with 8GB RAM.", ("NVIDIA GeForce RTX 3050 Ti", "1200.0", "8")),
    ("I'm interested in a laptop with AMD Ryzen 9 6900HX CPU, priced at 2500 with 32GB of RAM.", ("AMD Ryzen 9 6900HX", "2500.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1660 GPU, priced at $1000 with 8GB RAM.", ("NVIDIA GeForce GTX 1660", "1000.0", "8")),
    ("This laptop features an AMD Ryzen 5 5500U CPU, priced at $900 with 8GB of memory.", ("AMD Ryzen 5 5500U", "900.0", "8")),
    ("I want a laptop with Intel Iris Xe MAX Graphics, priced at $1100 with 16GB RAM.", ("Intel Iris Xe MAX Graphics", "1100.0", "16")),
    ("The laptop comes with NVIDIA GeForce RTX 3050 GPU, priced at $1300 with 16GB of RAM.", ("NVIDIA GeForce RTX 3050", "1300.0", "16")),
    ("This laptop has an AMD Ryzen 7 5800U CPU, priced at $1200 with 16GB RAM.", ("AMD Ryzen 7 5800U", "1200.0", "16")),
    ("Looking for a laptop with Intel UHD Graphics 620, priced at $800 with 8GB of RAM.", ("Intel UHD Graphics 620", "800.0", "8")),
    ("This laptop features NVIDIA GeForce GTX 1650 Max-Q GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Max-Q", "1400.0", "16")),
    ("I need a laptop with AMD Ryzen 9 5900HS CPU, priced at 2000 with 32GB RAM.", ("AMD Ryzen 9 5900HS", "2000.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce MX350 GPU, priced at $1000 with 8GB of memory.", ("NVIDIA GeForce MX350", "1000.0", "8")),
    ("This laptop has Intel HD Graphics 620, priced at 900 with 8GB RAM.", ("Intel HD Graphics 620", "900.0", "8")),
    ("I want a laptop with AMD Radeon RX Vega 8 GPU, priced at $700 with 8GB RAM.", ("AMD Radeon RX Vega 8", "700.0", "8")),
    ("The laptop comes with GeForce MX450 GPU, priced at $1100 with 16GB of RAM.", ("NVIDIA GeForce MX450", "1100.0", "16")),
    ("This laptop features an Intel Core i7-1165G7 CPU, priced at $1300 with 16GB RAM.", ("Intel Core i7-1165G7", "1300.0", "16")),
    ("I'm interested in a laptop with NVIDIA GeForce RTX 3060 Laptop GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce RTX 3060 Laptop", "1500.0", "16")),
    ("Looking for a laptop with AMD Ryzen 7 5800HS CPU, priced at $1800 with 32GB of memory.", ("AMD Ryzen 7 5800HS", "1800.0", "32")),
    ("This laptop has Intel UHD Graphics 630, priced at $900 with 8GB of RAM.", ("Intel UHD Graphics 630", "900.0", "8")),
    ("I need a laptop with NVIDIA GeForce RTX 3050 Laptop GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce RTX 3050", "1500.0", "16")),
    ("Looking for a laptop with AMD Radeon RX 5500M GPU, priced at $1400 with 16GB of memory.", ("AMD Radeon RX 5500M", "1400.0", "16")),
    ("This laptop has Intel Core i5-1135G7 CPU, priced at $1100 with 8GB RAM.", ("Intel Core i5-1135G7", "1100.0", "8")),
    ("I'm interested in a laptop with NVIDIA GeForce MX330 GPU, priced at $800 with 8GB of RAM.", ("NVIDIA GeForce MX330", "800.0", "8")),
    ("Looking for a laptop with AMD Ryzen 7 4700U CPU, priced at $1000 with 16GB RAM.", ("AMD Ryzen 7 4700U", "1000.0", "16")),
    ("This laptop features Intel UHD Graphics 630 , priced at $900 with 8GB RAM.", ("Intel UHD Graphics 630", "900.0", "8")),
    ("I want a laptop with NVIDIA GeForce GTX 1650 Ti GPU, priced at $1200 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Ti", "1200.0", "16")),
    ("The laptop comes with AMD Radeon RX 5600M GPU, priced at $1600 with 16GB of RAM.", ("AMD Radeon RX 5600M", "1600.0", "16")),
    ("This laptop has Intel Core i7-10750H CPU, priced at $1500 with 32GB RAM.", ("Intel Core i7-10750H", "1500.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1660 Ti GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1400.0", "16")),
    ("I need a laptop with Ryzen 5 4600H CPU, priced at $1200 with 8GB of memory.", ("AMD Ryzen 5 4600H", "1200.0", "8")),
    ("This laptop features Intel Iris Xe Graphics , priced at $1000 with 8GB RAM.", ("Intel Iris Xe Graphics", "1000.0", "8")),
    ("I'm interested in a laptop with NVIDIA GeForce RTX 3060 GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce RTX 3060", "1500.0", "16")),
    ("Looking for a laptop with AMD Radeon RX 6700M GPU, priced at $1800 with 16GB of memory.", ("AMD Radeon RX 6700M", "1800.0", "16")),
    ("This laptop has Intel Core i9 CPU, priced at $2500 with 32GB RAM.", ("Intel Core i9", "2500.0", "32")),
    ("I want a laptop with NVIDIA GeForce MX GPU, priced at $1100 with 16GB RAM.", ("NVIDIA GeForce MX", "1100.0", "16")),
    ("This laptop features Intel UHD Graphics 620 , priced at $800 with 8GB RAM.", ("Intel UHD Graphics 620", "800.0", "8")),
    ("I need a laptop with GeForce RTX 3070 GPU, priced at $2000 with 16GB RAM.", ("NVIDIA GeForce RTX 3070", "2000.0", "16")),
    ("This laptop has an NVIDIA GeForce GTX 1660 Ti GPU, priced at $1200 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1200.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580 GPU, priced at $900 with 8GB of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("I need a laptop with 16GB RAM, AMD Radeon Pro 455 and with a price of $1500", ("AMD Radeon Pro 455", "1500.0", "16")),
    ("Looking for a laptop with NVIDIA GeForce RTX 3070 GPU, priced at $2000 with 32GB of RAM.", ("NVIDIA GeForce RTX 3070", "2000.0", "32")),
    ("This laptop features an Intel Iris Xe Graphics, priced at $1100 with 16GB RAM.", ("Intel Iris Xe Graphics", "1100.0", "16")),
    ("The laptop comes with an NVIDIA Quadro RTX 5000 GPU, priced at $2500 with 64GB of RAM.", ("NVIDIA Quadro RTX 5000", "2500.0", "64")),
    ("I want a laptop with AMD Radeon RX Vega 10 GPU, priced at $800 with 8GB RAM.", ("AMD Radeon RX Vega 10", "800.0", "8")),
    ("This laptop has an NVIDIA GeForce GTX 1650 Ti GPU, priced at $1500 with 32GB RAM.", ("NVIDIA GeForce GTX 1650 Ti", "1500.0", "32")),
    ("I'm interested in a laptop with NVIDIA GeForce GTX 1660 Ti GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Ti", "1400.0", "16")),
    ("The laptop comes with an AMD Radeon RX 580 GPU, priced at $900 with 8 of RAM.", ("AMD Radeon RX 580", "900.0", "8")),
    ("This laptop comes with Radeon RX 6700 XT GPU, priced at $1800 with 16GB RAM.", ("AMD Radeon RX 6700 XT", "1800.0", "16")),
    ("Looking for a laptop featuring Intel Core i7-11800H CPU, priced at $1700 with 16GB of memory.", ("Intel Core i7-11800H", "1700.0", "16")),
    ("This laptop has NVIDIA GeForce GTX 1650 Max-Q GPU, priced at $1400 with 8GB RAM.", ("NVIDIA GeForce GTX 1650 Max-Q", "1400.0", "8")),
    ("I'm interested in a laptop with AMD Ryzen 9 5900HS CPU, priced at $2000 with 32GB of RAM.", ("AMD Ryzen 9 5900HS", "2000.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce MX350 GPU, priced at $1000 with 8GB of memory.", ("NVIDIA GeForce MX350", "1000.0", "8")),
    ("This laptop features an Intel Core i5-11300H CPU, priced at $1200 with 16GB of memory.", ("Intel Core i5-11300H", "1200.0", "16")),
    ("I want a laptop with Intel Iris Xe MAX Graphics, priced at $1100 with 16GB RAM.", ("Intel Iris Xe MAX Graphics", "1100.0", "16")),
    ("The laptop comes with NVIDIA GeForce RTX 3050 GPU, priced at $1300 with 16GB of RAM.", ("NVIDIA GeForce RTX 3050", "1300.0", "16")),
    ("This laptop has an AMD Ryzen 7 5800U CPU, priced at $1200 with 16GB RAM.", ("AMD Ryzen 7 5800U", "1200.0", "16")),
    ("Looking for a laptop with Intel UHD Graphics 620, priced at $800 with 8GB of RAM.", ("Intel UHD Graphics 620", "800.0", "8")),
    ("This laptop features NVIDIA GeForce GTX 1650 Max-Q GPU, priced at $1400 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Max-Q", "1400.0", "16")),
    ("I need a laptop with AMD Ryzen 9 5900HS CPU, priced at $2000 with 32GB RAM.", ("AMD Ryzen 9 5900HS", "2000.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce MX350 GPU, priced at $1000 with 8GB of memory.", ("NVIDIA GeForce MX350", "1000.0", "8")),
    ("This laptop has Intel HD Graphics 620, priced at $900 with 8GB RAM.", ("Intel HD Graphics 620", "900.0", "8")),
    ("I want a laptop with AMD Radeon RX Vega 8 GPU, priced at $700 with 8GB RAM.", ("AMD Radeon RX Vega 8", "700.0", "8")),
    ("The laptop comes with NVIDIA GeForce MX450 GPU, priced at $1100 with 16GB of RAM.", ("NVIDIA GeForce MX450", "1100.0", "16")),
    ("This laptop features an Intel Core i7-1165G7, priced at $1300 with 16GB RAM.", ("Intel Core i7-1165G7", "1300.0", "16")),
    ("I'm interested in a laptop with GeForce RTX 3060 Laptop GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce RTX 3060 Laptop", "1500.0", "16")),
    ("Looking for a laptop with AMD Ryzen 7 5800HS CPU, priced at $1800 with 32GB of memory.", ("AMD Ryzen 7 5800HS", "1800.0", "32")),
    ("This laptop has Intel UHD Graphics 630, priced at $900 with 8GB of RAM.", ("Intel UHD Graphics 630", "900.0", "8")),
    ("This laptop comes with Radeon RX 6800 XT GPU, priced at $2200 with 32GB RAM.", ("AMD Radeon RX 6800 XT", "2200.0", "32")),
    ("Looking for a laptop featuring Intel Core i5-11400H CPU, priced at $1200 with 16GB of memory.", ("Intel Core i5-11400H", "1200.0", "16")),
    ("This laptop has NVIDIA GeForce GTX 1660 Super GPU, priced at $1300 with 16GB RAM.", ("NVIDIA GeForce GTX 1660 Super", "1300.0", "16")),
    ("I'm interested in a laptop with AMD Ryzen 7 5800X CPU, priced at $2500 with 32GB of RAM.", ("AMD Ryzen 7 5800X", "2500.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce GTX 1660 Ti Max-Q GPU, priced at $1100 with 8GB RAM.", ("NVIDIA GeForce GTX 1660 Ti Max-Q", "1100.0", "8")),
    ("This laptop features an AMD Ryzen 5 5600H CPU, priced at $1300 with 16GB of memory.", ("AMD Ryzen 5 5600H", "1300.0", "16")),
    ("I want a laptop with Intel Iris Xe Graphics G4, priced at $1000 with 16GB RAM.", ("Intel Iris Xe Graphics G4", "1000.0", "16")),
    ("The laptop comes with NVIDIA GeForce RTX 3060 GPU, priced at $1400 with 16GB of RAM.", ("NVIDIA GeForce RTX 3060", "1400.0", "16")),
    ("This laptop has an AMD Ryzen 7 5700U CPU, priced at $1300 with 16GB RAM.", ("AMD Ryzen 7 5700U", "1300.0", "16")),
    ("Looking for a laptop with Intel UHD Graphics 730, priced at $900 with 8GB of RAM.", ("Intel UHD Graphics 730", "900.0", "8")),
    ("This laptop features NVIDIA GeForce GTX 1650 Ti Max-Q GPU, priced at $1500 with 16GB RAM.", ("NVIDIA GeForce GTX 1650 Ti Max-Q", "1500.0", "16")),
    ("I need a laptop with AMD Ryzen 9 5950HS CPU, priced at $2200 with 32GB RAM.", ("AMD Ryzen 9 5950HS", "2200.0", "32")),
    ("Looking for a laptop with NVIDIA GeForce MX450 GPU, priced at $1100 with 8GB of memory.", ("NVIDIA GeForce MX450", "1100.0", "8")),
    ("This laptop has Intel HD Graphics 630, priced at $1000 with 8GB RAM.", ("Intel HD Graphics 630", "1000.0", "8")),
    ("I want a laptop with Radeon RX Vega 11 GPU, priced at $800 with 8GB RAM.", ("AMD Radeon RX Vega 11", "800.0", "8")),
    ("The laptop comes with GeForce MX350 GPU, priced at $1200 with 16GB of RAM.", ("NVIDIA GeForce MX350", "1200.0", "16")),
    ("This laptop features an Intel Core i7-1185G7 CPU, priced at $1400 with 16GB RAM.", ("Intel Core i7-1185G7", "1400.0", "16")),
    ("I'm interested in a laptop with GeForce RTX 3060 Laptop GPU, priced at $1600 with 16GB RAM.", ("NVIDIA GeForce RTX 3060 Laptop", "1600.0", "16")),
    ("Looking for a laptop with AMD Ryzen 7 5800HS CPU, priced at $1900 with 32GB of memory.", ("AMD Ryzen 7 5800HS", "1900.0", "32")),
    ("This laptop has Intel UHD Graphics 730, priced at 100000 rupees with 8GB of RAM.", ("Intel UHD Graphics 730", "1000.0", "8")),   
]

# %%
import spacy
from sklearn.metrics import classification_report

# Load your trained spaCy model
nlp = spacy.load("en_core_web_lg")

# Function to extract GPU, price, and RAM information from a sentence
def extract_info(sentence):
    """Preprocess the text using spaCy."""
    doc = nlp(sentence)
    # Extract price, RAM, and GPU information
    price = None
    ram = None
    gpu = None
    word_list = sentence.split()
    # Initialize variables to store the words between "and" and "GPU"
    words_between = []
    # Iterate through tokens in the document
    for i, token in enumerate(doc):
        # Check if the token text is 'price'
        if token.text.lower() == '$':
            # Check if the next token resembles a number
            if i + 1 < len(doc) and doc[i + 1].like_num:
                # Extract the numerical value of the next token
                price = float(doc[i + 1].text)
        elif token.text.lower() == 'gb':
            # Check if the next token resembles a number
            if i + 1 < len(doc) and doc[i - 1].like_num:
                # Extract the numerical value of the next token
                ram = int(doc[i - 1].text)

        # Check if the token text is 'nvidia' or 'amd'
        if token.text.lower() in ['nvidia', 'amd', 'intel']:
            for j in range(0, len(word_list)):
                if word_list[j].lower() in ['nvidia', 'amd', 'intel']:
                    words_between.append(word_list[j])
                    for k in range(j+1, len(word_list)):
                        if word_list[k].lower() in [".", "and", "gpu", ",", "gpu,", "cpu,", "gpu.", "cpu."]:
                            break
                        else:
                            words_between.append(word_list[k])
                    break 
            if len(words_between) >= 6:
                words_between.clear()
                words_between.append(token.text)
                for j in range(i + 1, len(doc)):
                    if doc[j].text.lower() in [".", "and", "gpu", ",", "cpu"]:
                        break
                    else:
                        words_between.append(doc[j].text)
                

    # Convert the list of words between 'and' and 'GPU' to a string
    if len(words_between) == 0:
        gpu = "None"
    else:
        gpu = ' '.join(words_between)
    # gpu = ' '.join(words_between)
    
    if price == None:
        price = 0.0
        
    if ram == None:
        ram = 0
    return gpu, price, ram

# Evaluation dataset (list of tuples containing sentence and ground truth labels)


# Lists to store predicted and ground truth labels
predicted_labels = {"GPU": [], "PRICE": [], "RAM": []}
true_labels = {"GPU": [], "PRICE": [], "RAM": []}

# Iterate over evaluation dataset
for sentence, (true_gpu, true_price, true_ram) in evaluation_data:
    predicted_gpu, predicted_price, predicted_ram = extract_info(sentence)

    predicted_labels["GPU"].append(predicted_gpu)
    predicted_labels["PRICE"].append(predicted_price)
    predicted_labels["RAM"].append(predicted_ram)
    
    true_labels["GPU"].append(true_gpu)
    true_labels["PRICE"].append(float(true_price))
    true_labels["RAM"].append(int(true_ram))

# Compute classification report for GPU, price, and RAM extraction
for label in ["GPU", "PRICE", "RAM"]:
    print(f"Classification Report for {label}:")
    print(classification_report(true_labels[label], predicted_labels[label]))
# Out:
# Classification Report for GPU:
#                                     precision    recall  f1-score   support
#
#                 AMD Radeon Pro 455       1.00      1.00      1.00         4
#                AMD Radeon RX 5500M       1.00      1.00      1.00         1
#              AMD Radeon RX 5600 XT       1.00      1.00      1.00         1
#                AMD Radeon RX 5600M       1.00      1.00      1.00         1
#                  AMD Radeon RX 580       1.00      0.88      0.93         8
#              AMD Radeon RX 6600 XT       1.00      1.00      1.00         1
#                AMD Radeon RX 6600M       1.00      1.00      1.00         1
#              AMD Radeon RX 6700 XT       1.00      0.75      0.86         4
#                AMD Radeon RX 6700M       1.00      1.00      1.00         2
#                 AMD Radeon RX 6800       1.00      1.00      1.00         1
#              AMD Radeon RX 6800 XT       0.00      0.00      0.00         1
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(true_labels, predicted_labels, labels):
    cm = confusion_matrix(true_labels, predicted_labels, labels=labels)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Compute confusion matrix for GPU, price, and RAM extraction
for label in ["GPU", "PRICE", "RAM"]:
    print(f"Confusion Matrix for {label}:")
    unique_labels = set(true_labels[label] + predicted_labels[label])
    plot_confusion_matrix(true_labels[label], predicted_labels[label], labels=sorted(unique_labels))
# Out:
# Confusion Matrix for GPU:
# Confusion Matrix for PRICE:
# Confusion Matrix for RAM:
